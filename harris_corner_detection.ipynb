# %%
import numpy as np
import matplotlib.pyplot as plt
from harris_corner_detection import *
from PIL import Image
import cv2

# %%
img = Image.open('Images/image1.jfif')
img = np.array(img)

plt.imshow(img, cmap='gray')
xticks = plt.xticks([])
yticks = plt.yticks([])

# %%
edge_img = harris_corner_detection(img, k=0.06)

plt.imshow(edge_img, cmap='gray')
xticks = plt.xticks([])
yticks = plt.yticks([])
