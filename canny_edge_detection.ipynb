# %%
import numpy as np
import matplotlib.pyplot as plt
from canny_edge_detection import *
from PIL import Image
import cv2

# %%
img = Image.open('Images/image1.jfif')
img = np.array(img)

plt.imshow(img, cmap='gray')
xticks = plt.xticks([])
yticks = plt.yticks([])

# %%
edge_img = edge_detector(img, sigma=1, low_thresh=1.1475, high_thresh=22.95)

plt.imshow(edge_img, cmap='gray')
xticks = plt.xticks([])
yticks = plt.yticks([])
